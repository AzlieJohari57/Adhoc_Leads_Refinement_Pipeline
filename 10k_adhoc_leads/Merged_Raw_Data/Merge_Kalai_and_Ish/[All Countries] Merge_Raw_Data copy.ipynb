# %% [markdown]
# ### Cleaning/Filtering Done on Excel Before Moving Here
#
# 1. Renaming columns to Company_Name, PIC_Name, Designation, Contact_Number, Email_Address, Address
#
# 2. Concatenation for PIC_Name (combine First Name and Last Name columns)

# %%
import pandas as pd
import glob
import os
import re

# %% [markdown]
# ### Merge Adhoc Leads _F&B.xlsx Into One Tab

# %%
# Path to your Excel file
file_path = "Adhoc Leads_F&B.xlsx"

# # Optional: function to clean Singapore numbers (8 digits)
# def clean_sg_number(val):
#     if pd.isna(val):
#         return None
#     digits = re.sub(r"\D", "", str(val))
#     if digits.startswith("65") and len(digits) > 8:
#         digits = digits[2:]
#     if len(digits) == 8 and digits[0] in ["6", "8", "9"]:
#         return digits
#     return None

# Load the Excel workbook
excel = pd.ExcelFile(file_path)
print("Sheets in workbook:", excel.sheet_names)

dfs = []

for sheet in excel.sheet_names:
    sheet_clean = sheet.strip()  # Remove leading/trailing whitespace
    print("Processing sheet:", repr(sheet_clean))

    try:
        df = excel.parse(sheet_clean)
    except Exception as e:
        print(f"  Skipping sheet '{sheet_clean}' due to error:", e)
        continue

    if df.empty:
        print(f"  Skipping empty sheet: {sheet_clean}")
        continue

    # Standardize column names
    df.columns = df.columns.str.strip().str.lower()

    # Optional: clean contact numbers
    # for i in range(1, 9):
    #     col = f"contact_number {i}"
    #     if col in df.columns:
    #         df[col] = df[col].apply(clean_sg_number)

    dfs.append(df)

# Merge all sheets
if not dfs:
    raise ValueError("No sheets with data found in the workbook.")

merged_df = pd.concat(dfs, ignore_index=True, sort=False)

# Desired columns
selected_columns = [
    "company_name",
    "pic_name",
    "designation",
    "contact_number 1",
    "contact_number 2",
    "contact_number 3",
    "contact_number 4",
    "contact_number 5",
    "contact_number 6",
    "contact_number 7",
    "contact_number 8",
    "email_address",
    "address"
]

# Keep only columns that exist
final_columns = [col for col in selected_columns if col in merged_df.columns]
merged_df = merged_df[final_columns]

# Keep only rows where 'contact_number 1' is non-empty
if "contact_number 1" in merged_df.columns:
    merged_df = merged_df[merged_df["contact_number 1"].notna() & (merged_df["contact_number 1"].astype(str).str.strip() != "")]

print("Rows retained with non-empty contact_number 1:", len(merged_df))

# Save to Excel
output_file = "Merged_Adhoc_Leads_F&B.xlsx"
merged_df.to_excel(output_file, index=False)
print(f"✅ Merged file saved as '{output_file}' successfully.")
# Out:
# Sheets in workbook: ['SG & MY Adhoc', 'From Quickbooks', 'F&B Lite_1', 'F&B Lite', 'F&B Enterprise High level Accou']
# Processing sheet: 'SG & MY Adhoc'
#   Skipping sheet 'SG & MY Adhoc' due to error: Value must be either numerical or a string containing a wildcard
# Processing sheet: 'From Quickbooks'
# Processing sheet: 'F&B Lite_1'
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G103 is marked as a date but the serial value 67388548 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H103 is marked as a date but the serial value 62222671 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G169 is marked as a date but the serial value 64384567 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G177 is marked as a date but the serial value 67388548 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H177 is marked as a date but the serial value 62222671 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G184 is marked as a date but the serial value 67388548 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H184 is marked as a date but the serial value 62222671 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G652 is marked as a date but the serial value 63366908 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G871 is marked as a date but the serial value 67388548 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H871 is marked as a date but the serial value 62222671 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G1294 is marked as a date but the serial value 67388548 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1294 is marked as a date but the serial value 62222671 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G1356 is marked as a date but the serial value 63528285 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1356 is marked as a date but the serial value 65833055 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1445 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1446 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1450 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1454 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1502 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1503 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1506 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1507 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1509 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1514 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1516 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1517 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1519 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1522 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1564 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1565 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1567 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1569 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1576 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1577 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1578 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1579 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1580 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1583 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1584 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1586 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1630 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1631 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1633 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1634 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1635 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1637 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1639 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1640 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1641 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1642 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1644 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H1648 is marked as a date but the serial value 91386330 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G2038 is marked as a date but the serial value 84380595 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G2096 is marked as a date but the serial value 63840115 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G2129 is marked as a date but the serial value 62238068 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G2133 is marked as a date but the serial value 61425936886 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H2133 is marked as a date but the serial value 61396397723 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell I2133 is marked as a date but the serial value 61398180066 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell J2133 is marked as a date but the serial value 84233872 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G2242 is marked as a date but the serial value 66049662 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G2292 is marked as a date but the serial value 94781995 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G2778 is marked as a date but the serial value 63366908 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G2781 is marked as a date but the serial value 63366908 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G3025 is marked as a date but the serial value 61425936886 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H3025 is marked as a date but the serial value 61396397723 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell I3025 is marked as a date but the serial value 61398180066 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell J3025 is marked as a date but the serial value 84233872 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G3094 is marked as a date but the serial value 85004783 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G3362 is marked as a date but the serial value 64114990 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G3647 is marked as a date but the serial value 83427367 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G4383 is marked as a date but the serial value 65032533 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G4385 is marked as a date but the serial value 97526125 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H4385 is marked as a date but the serial value 62244996 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G4407 is marked as a date but the serial value 68417574 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H5444 is marked as a date but the serial value 85331006 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell H5703 is marked as a date but the serial value 85331006 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G5982 is marked as a date but the serial value 91384753 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G5996 is marked as a date but the serial value 97415861 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G6239 is marked as a date but the serial value 8884466875 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G6248 is marked as a date but the serial value 6596690385 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Cell G6250 is marked as a date but the serial value 6591263411 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# Processing sheet: 'F&B Lite'
# Processing sheet: 'F&B Enterprise High level Accou'
# Rows retained with non-empty contact_number 1: 9282
# ✅ Merged file saved as 'Merged_Adhoc_Leads_F&B.xlsx' successfully.

# %% [markdown]
# ### Merge F&B Prospects from Ishwarya's Own.xlsx Into One Tab

# %%
# Path to your Excel file
file_path = r"C:\Users\teele\Documents\GitHub\Adhoc_Leads_Refinement_Pipeline\10k_adhoc_leads\Merged_Raw_Data\Merge_Kalai_and_Ish\F&B Prospects from Ishwarya's Own.xlsx"

# # Optional: function to clean Singapore numbers (8 digits)
# def clean_sg_number(val):
#     if pd.isna(val):
#         return None
#     digits = re.sub(r"\D", "", str(val))
#     if digits.startswith("65") and len(digits) > 8:
#         digits = digits[2:]
#     if len(digits) == 8 and digits[0] in ["6", "8", "9"]:
#         return digits
#     return None

# Load the Excel workbook
excel = pd.ExcelFile(file_path)
print("Sheets in workbook:", excel.sheet_names)

dfs = []

for sheet in excel.sheet_names:
    sheet_clean = sheet.strip()  # Remove leading/trailing whitespace
    print("Processing sheet:", repr(sheet_clean))

    try:
        df = excel.parse(sheet_clean)
    except Exception as e:
        print(f"  Skipping sheet '{sheet_clean}' due to error:", e)
        continue

    if df.empty:
        print(f"  Skipping empty sheet: {sheet_clean}")
        continue

    # Standardize column names
    df.columns = df.columns.str.strip().str.lower()

    # Optional: clean contact numbers
    # for i in range(1, 9):
    #     col = f"contact_number {i}"
    #     if col in df.columns:
    #         df[col] = df[col].apply(clean_sg_number)

    dfs.append(df)

# Merge all sheets
if not dfs:
    raise ValueError("No sheets with data found in the workbook.")

merged_df = pd.concat(dfs, ignore_index=True, sort=False)

# Desired columns
selected_columns = [
    "company_name",
    "pic_name",
    "designation",
    "contact_number 1",
    "contact_number 2",
    "contact_number 3",
    "contact_number 4",
    "contact_number 5",
    "contact_number 6",
    "contact_number 7",
    "contact_number 8",
    "email_address",
    "address"
]

# Keep only columns that exist
final_columns = [col for col in selected_columns if col in merged_df.columns]
merged_df = merged_df[final_columns]

# Keep only rows where 'contact_number 1' is non-empty
if "contact_number 1" in merged_df.columns:
    merged_df = merged_df[merged_df["contact_number 1"].notna() & (merged_df["contact_number 1"].astype(str).str.strip() != "")]

print("Rows retained with non-empty contact_number 1:", len(merged_df))

# Save to Excel
output_file = "Merged_F&B_Prospects_from_Ishwarya's_Own.xlsx"
merged_df.to_excel(output_file, index=False)
print(f"✅ Merged file saved as '{output_file}' successfully.")
# Out:
# Sheets in workbook: ['Mr project 2023-2024 F&B segmen', 'Ishwarya Intern Sales newjoinee', 'Ishwarya_MR2022', 'Ishwarya_Inquiry to Ishwarya In', 'Sheet9', 'Ishwarya_Field Sales @ EXPO QSR', 'F&B Market research 2023']
# Processing sheet: 'Mr project 2023-2024 F&B segmen'
# Processing sheet: 'Ishwarya Intern Sales newjoinee'
# Processing sheet: 'Ishwarya_MR2022'
# Processing sheet: 'Ishwarya_Inquiry to Ishwarya In'
# Processing sheet: 'Sheet9'
# Processing sheet: 'Ishwarya_Field Sales @ EXPO QSR'
# Processing sheet: 'F&B Market research 2023'
# Rows retained with non-empty contact_number 1: 1614
# ✅ Merged file saved as 'Merged_F&B_Prospects_from_Ishwarya's_Own.xlsx' successfully.

# %% [markdown]
# ### Merge SG EVENTS MASTER DATABASE (1).xlsx Into One Tab

# %%
# Path to your Excel file
file_path = r"C:\Users\teele\Documents\GitHub\Adhoc_Leads_Refinement_Pipeline\10k_adhoc_leads\Merged_Raw_Data\Merge_Kalai_and_Ish\SG EVENTS MASTER DATABASE (1).xlsx"

# # Optional: function to clean Singapore numbers (8 digits)
# def clean_sg_number(val):
#     if pd.isna(val):
#         return None
#     digits = re.sub(r"\D", "", str(val))
#     if digits.startswith("65") and len(digits) > 8:
#         digits = digits[2:]
#     if len(digits) == 8 and digits[0] in ["6", "8", "9"]:
#         return digits
#     return None

# Load the Excel workbook
excel = pd.ExcelFile(file_path)
print("Sheets in workbook:", excel.sheet_names)

dfs = []

for sheet in excel.sheet_names:
    sheet_clean = sheet.strip()  # Remove leading/trailing whitespace
    print("Processing sheet:", repr(sheet_clean))

    try:
        df = excel.parse(sheet_clean)
    except Exception as e:
        print(f"  Skipping sheet '{sheet_clean}' due to error:", e)
        continue

    if df.empty:
        print(f"  Skipping empty sheet: {sheet_clean}")
        continue

    # Standardize column names
    df.columns = df.columns.str.strip().str.lower()

    # Optional: clean contact numbers
    # for i in range(1, 9):
    #     col = f"contact_number {i}"
    #     if col in df.columns:
    #         df[col] = df[col].apply(clean_sg_number)

    dfs.append(df)

# Merge all sheets
if not dfs:
    raise ValueError("No sheets with data found in the workbook.")

merged_df = pd.concat(dfs, ignore_index=True, sort=False)

# Desired columns
selected_columns = [
    "company_name",
    "pic_name",
    "designation",
    "contact_number 1",
    "contact_number 2",
    "contact_number 3",
    "contact_number 4",
    "contact_number 5",
    "contact_number 6",
    "contact_number 7",
    "contact_number 8",
    "email_address",
    "address"
]

# Keep only columns that exist
final_columns = [col for col in selected_columns if col in merged_df.columns]
merged_df = merged_df[final_columns]

# Keep only rows where 'contact_number 1' is non-empty
if "contact_number 1" in merged_df.columns:
    merged_df = merged_df[merged_df["contact_number 1"].notna() & (merged_df["contact_number 1"].astype(str).str.strip() != "")]

print("Rows retained with non-empty contact_number 1:", len(merged_df))

# Save to Excel
output_file = "Merged_SG_EVENTS_MASTER_DATABASE_(1).xlsx"
merged_df.to_excel(output_file, index=False)
print(f"✅ Merged file saved as '{output_file}' successfully.")
# Out:
# Sheets in workbook: ['QSR Media Conf 2024 ', 'Restaurant ASIA 2023', 'QSR 2023_April ', 'FHA 2022', 'food2go_belinda & brandon', '2022_May Restaurant ASIA (un as', '2022_May Restaurant Asia (Brand', '2022_May Restaurant ASIA (Kevin', 'GRLC 2019', 'FHA 2018-Whole', 'Burger King Event January 2020', 'FHA 2018-Mike', 'RAS AGM 15 Aug 18', 'SGPC 24 May', 'SME Day 15-16 May', 'Kiosk Lite Canvassing', 'QSR event 31st Jan', 'Restaurant Asia 2019']
# Processing sheet: 'QSR Media Conf 2024'
#   Skipping sheet 'QSR Media Conf 2024' due to error: Worksheet named 'QSR Media Conf 2024' not found
# Processing sheet: 'Restaurant ASIA 2023'
# Processing sheet: 'QSR 2023_April'
#   Skipping sheet 'QSR 2023_April' due to error: Worksheet named 'QSR 2023_April' not found
# Processing sheet: 'FHA 2022'
# Processing sheet: 'food2go_belinda & brandon'
# Processing sheet: '2022_May Restaurant ASIA (un as'
# Processing sheet: '2022_May Restaurant Asia (Brand'
# Processing sheet: '2022_May Restaurant ASIA (Kevin'
# Processing sheet: 'GRLC 2019'
# Processing sheet: 'FHA 2018-Whole'
# Processing sheet: 'Burger King Event January 2020'
# Processing sheet: 'FHA 2018-Mike'
# Processing sheet: 'RAS AGM 15 Aug 18'
# Processing sheet: 'SGPC 24 May'
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# Processing sheet: 'SME Day 15-16 May'
# Processing sheet: 'Kiosk Lite Canvassing'
# Processing sheet: 'QSR event 31st Jan'
# Processing sheet: 'Restaurant Asia 2019'
# Rows retained with non-empty contact_number 1: 617
# ✅ Merged file saved as 'Merged_SG_EVENTS_MASTER_DATABASE_(1).xlsx' successfully.
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# c:\Users\teele\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %% [markdown]
# ### Merge All Three Files: Merged_Adhoc_Leads_F&B.xlsx, Merged_F&B Prospects from Ishwarya's Own.xlsx & Merged_SG EVENTS MASTER DATABASE (1).xlsx

# %%
import pandas as pd
import os
import glob

# Folder path containing your Excel files
folder_path = r"C:\Users\teele\Documents\GitHub\Adhoc_Leads_Refinement_Pipeline\10k_adhoc_leads\Merged_Raw_Data\Merge_Kalai_and_Ish"

# Only the specific files you want to merge
files_to_merge = [
    "Merged_Adhoc_Leads_F&B.xlsx",
    "Merged_F&B_Prospects_from_Ishwarya's_Own.xlsx",
    "Merged_SG_EVENTS_MASTER_DATABASE_(1).xlsx"
]

# Build full file paths
excel_files = [os.path.join(folder_path, f) for f in files_to_merge]

# Columns to keep
selected_columns = [
    "company_name",
    "pic_name",
    "designation",
    "contact_number 1",
    "contact_number 2",
    "contact_number 3",
    "contact_number 4",
    "contact_number 5",
    "contact_number 6",
    "contact_number 7",
    "contact_number 8",
    "email_address",
    "address"
]

# List to store all dataframes
dfs = []

for file in excel_files:
    # Load all sheets in the current Excel file
    excel = pd.ExcelFile(file)
    
    for sheet in excel.sheet_names:
        df = excel.parse(sheet)
        
        # Standardize column names
        df.columns = df.columns.str.strip().str.lower()
        
        # Keep only selected columns that exist in the file
        df = df[[col for col in selected_columns if col in df.columns]]
        
        dfs.append(df)

# Merge all dataframes
merged_df = pd.concat(dfs, ignore_index=True, sort=False)

# Ensure all selected columns exist (fill missing ones with blank)
for col in selected_columns:
    if col not in merged_df.columns:
        merged_df[col] = ""

# Reorder columns
merged_df = merged_df[selected_columns]

# Save to Excel
merged_df.to_excel("Merged_Multiple_Raw_Data_Files.xlsx", index=False)

print("✅ Successfully merged ONLY the 3 specified files → 'Merged_Multiple_Raw_Data_Files.xlsx'")
# Out:
# ✅ Successfully merged ONLY the 3 specified files → 'Merged_Multiple_Raw_Data_Files.xlsx'

# %% [markdown]
# ### Remove duplicated contact numbers within the output (merged adhoc data files)

# %%
# Path to your Excel file
file_path = r"C:\Users\teele\Documents\GitHub\Adhoc_Leads_Refinement_Pipeline\10k_adhoc_leads\Merged_Raw_Data\Merge_Kalai_and_Ish\Merged_Multiple_Raw_Data_Files.xlsx"

# Load the Excel file (assuming single sheet)
df = pd.read_excel(file_path)

# Standardize column names
df.columns = df.columns.str.strip().str.lower()

# Ensure 'contact_number 1' exists
if "contact_number 1" not in df.columns:
    raise ValueError("'contact_number 1' column not found in the Excel file.")

# Remove rows with duplicated 'contact_number 1', keeping only the first occurrence
df_cleaned = df.drop_duplicates(subset="contact_number 1", keep="first")

print("Original rows:", len(df))
print("Rows after removing duplicates based on contact_number 1:", len(df_cleaned))

# Save the cleaned file
output_file = "Merged_Multiple_Raw_Data_Files_NoDuplicates.xlsx"
df_cleaned.to_excel(output_file, index=False)
print(f"✅ Cleaned file saved as '{output_file}'.")
# Out:
# Original rows: 11513
# Rows after removing duplicates based on contact_number 1: 7187
# ✅ Cleaned file saved as 'Merged_Multiple_Raw_Data_Files_NoDuplicates.xlsx'.

# %% [markdown]
# ### Check for Duplication with Master DB

# %%
# # -------------------------------
# # 1. Helper function: clean SG number
# # -------------------------------
# def clean_sg_number(val):
#     if pd.isna(val):
#         return None

#     # Convert float like 65131787.0 to 65131787
#     if isinstance(val, float):
#         val = str(int(val))
#     else:
#         val = str(val)

#     # keep digits only
#     digits = re.sub(r"\D", "", val)

#     # remove leading 65 (country code)
#     if digits.startswith("65") and len(digits) > 8:
#         digits = digits[2:]

#     # valid SG number = 8 digits, starts with 6/8/9
#     if len(digits) == 8 and digits[0] in ["6", "8", "9"]:
#         return digits

#     return None

# %%
# -------------------------------
# 2. File 1: Merged_Multiple_Raw_Data_Files_NoDuplicates.xlsx
# -------------------------------

file1 = r"C:\Users\teele\Documents\GitHub\Adhoc_Leads_Refinement_Pipeline\10k_adhoc_leads\Merged_Raw_Data\Merge_Kalai_and_Ish\Merged_Multiple_Raw_Data_Files_NoDuplicates.xlsx"

file1_cols = [
    "contact_number 1", "contact_number 2", "contact_number 3", "contact_number 4",
    "contact_number 5", "contact_number 6", "contact_number 7", "contact_number 8"
]

df1 = pd.read_excel(file1)

# Standardize column names
df1.columns = df1.columns.str.strip().str.lower()

# Extract only columns that exist
file1_existing = [c for c in file1_cols if c in df1.columns]

# Flatten into a Series of cleaned numbers
numbers_file1 = (
    df1[file1_existing]
    .apply(lambda col: col.map(clean_sg_number))
    .values
    .ravel()
)

numbers_file1 = pd.Series([n for n in numbers_file1 if n is not None], name="number")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 23
#      18 file1_existing = [c for c in file1_cols if c in df1.columns]
#      20 # Flatten into a Series of cleaned numbers
#      21 numbers_file1 = (
#      22     df1[file1_existing]
# ---> 23     .apply(lambda col: col.map(clean_sg_number))
#      24     .values
#      25     .ravel()
#      26 )
#      28 numbers_file1 = pd.Series([n for n in numbers_file1 if n is not None], name="number")
#
# File c:\Users\teele\anaconda3\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\teele\anaconda3\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\teele\anaconda3\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\teele\anaconda3\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[10], line 23, in <lambda>(col)
#      18 file1_existing = [c for c in file1_cols if c in df1.columns]
#      20 # Flatten into a Series of cleaned numbers
#      21 numbers_file1 = (
#      22     df1[file1_existing]
# ---> 23     .apply(lambda col: col.map(clean_sg_number))
#      24     .values
#      25     .ravel()
#      26 )
#      28 numbers_file1 = pd.Series([n for n in numbers_file1 if n is not None], name="number")
#
# NameError: name 'clean_sg_number' is not defined

# %%
# -------------------------------
# 3. File 2: [18 Nov] Master DB.xlsx
# -------------------------------

file2 = "[18 Nov] Master DB.xlsx"

file2_cols = [
    "pic name 1 contact number 1", "pic name 1 contact number 2", 
    "pic name 1 contact number 3", "pic name 1 contact number 4",
    
    "pic name 2 contact number 1", "pic name 2 contact number 2",
    "pic name 2 contact number 3", "pic name 2 contact number 4",

    "pic name 3 contact number 1", "pic name 3 contact number 2",
    "pic name 3 contact number 3", "pic name 3 contact number 4"
]

df2 = pd.read_excel(file2)

# Standardize column names
df2.columns = df2.columns.str.strip().str.lower()

# Extract existing columns
file2_existing = [c for c in file2_cols if c in df2.columns]

# Flatten into a Series of cleaned numbers
numbers_file2 = (
    df2[file2_existing]
    .applymap(clean_sg_number)
    .values
    .ravel()
)

numbers_file2 = pd.Series([n for n in numbers_file2 if n is not None], name="number")
# Out:
# C:\Users\teele\AppData\Local\Temp\ipykernel_23372\4282091465.py:29: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   .applymap(clean_sg_number)

# %%
# -------------------------------
# 4. Find duplicates across the two files
# -------------------------------

# Convert to sets to identify duplicates
duplicates = set(numbers_file1).intersection(set(numbers_file2))

# Prepare result dataframe
result_df = pd.DataFrame({
    "number": list(duplicates),
    "count_in_file1": [sum(numbers_file1 == num) for num in duplicates],
    "count_in_file2": [sum(numbers_file2 == num) for num in duplicates],
})

# Sort result
result_df = result_df.sort_values("number").reset_index(drop=True)

# %%
# -------------------------------
# 5. Export to Excel
# -------------------------------

result_df.to_excel("Duplicated_Contact_Numbers.xlsx", index=False)

print("✅ Duplicate contact-number check completed!")
print(f"Total duplicated numbers found: {len(result_df)}")
print("📁 Output saved to: Duplicated_Contact_Numbers.xlsx")
# Out:
# ✅ Duplicate contact-number check completed!
# Total duplicated numbers found: 302
# 📁 Output saved to: Duplicated_Contact_Numbers.xlsx

# %% [markdown]
# ### Deduplicate the Cleaned Adhoc Leads from Ish (Merged_Multiple_Raw_Data_Files.xlsx) Against Master DB

# %%
# 1. Read the Excel files
try:
    df1 = pd.read_excel("Merged_Multiple_Raw_Data_Files.xlsx")
    df2 = pd.read_excel("Duplicated_Contact_Numbers.xlsx")
except FileNotFoundError as e:
    print(f"Error: {e}")
    exit()

# 2. Get the unique values from the exclusion column (File 2)
# Convert to a set for highly efficient lookup
values_to_exclude = set(df2["number"].dropna())

# Assuming 'columns_to_check_df1' is a list of column names in df1, e.g.,
columns_to_check_df1 = ["contact_number 1", "contact_number 2", "contact_number 3", "contact_number 4", "contact_number 5", "contact_number 6", "contact_number 7", "contact_number 8"]

# 3. Create a boolean mask for rows in df1 that should be dropped
# Check if any value across the specified columns in df1 exists in the exclusion set.

# Step 1: Apply isin() to the subset of columns. This returns a DataFrame of Booleans.
boolean_df = df1[columns_to_check_df1].isin(values_to_exclude)

# Step 2: Use .any(axis=1) to combine the column results for each row.
# This results in a Series where True means AT LEAST ONE of the contact columns 
# in that row contains a duplicate value.
rows_to_drop_mask = boolean_df.any(axis=1)

# 4. Filter df1 to keep ONLY the rows where the mask is False (i.e., NOT duplicates)
df1_cleaned = df1[~rows_to_drop_mask].copy()

# --- Output ---
print(f"Original shape of Merged_Multiple_Raw_Data_Files.xlsx: {df1.shape}")
print(f"Number of rows dropped: {rows_to_drop_mask.sum()}")
print(f"Cleaned shape of df1: {df1_cleaned.shape}")

# Optional: Save the cleaned DataFrame to a new file
df1_cleaned.to_excel("Ish_Merged_Multiple_Raw_Data_Files.xlsx", index=False)
# Out:
# Original shape of Merged_Multiple_Raw_Data_Files.xlsx: (18075, 13)
# Number of rows dropped: 503
# Cleaned shape of df1: (17572, 13)

# %% [markdown]
# ### Apply Constraints to Show Only Relevant Leads (SG only, no competitors, no delivery platforms, cleaned company name)
#
# 1. Email address:
# <!-- - Keeps only rows with email address ending with "sg" or "com"
# - Remove rows where the “company_name” column is blank and the “email_address” column contains only personal email addresses (with the “gmail”, “yahoo”, “singnet”, "hotmail" or "outlook" domain) -->
# - Remove rows containing these terms in the "email_address" column: “marketing”, “entertainment”
# - Remove rows containing "deliveryhero", "tabsquare", "grab" or "foodpanda" in the "email_address" column
# - For rows with blank "company_name" column but duplicated "email_address" input, remove the duplicated rows (keep the first occurence)
#
# 2. Company name:
# - Remove these texts from the “company_name” column: “SmartTerminals”, “deal”, “- Raptor List (Pay Only)”, “Incoming Lead_”, “FHA 2022_”, “EDM leads _”, “Google Ads Leads_”, “Speedster Campaign_”, “Fy23_”, “TabsquareConneXions_”, “QSR 2024 -”, “Pre Event 2024-”, “(SmartConnect)”, “FP23_”, “FY23_SG_RA_”, “TabsquareConneXions_”, “.. “
# - Remove these symbols (“_”, “*”, “|”) from the “company_name” column values
# - Remove rows where the "company_name" column contain "marketing" or "consulting"
#
# 3. Competitor: Exclude a row if the email address contains POS vendors' name
# - suntoyo
# - megasafe
# - appzgate
# - Qashier
# - Weebo
# - Azdigital
# - Hashmicro
# - Netiquette
# - Edgeworks
# - Foodzaps
# - Sgdatahub
# - Imetrics
# possquare
#
# 4. Remove rows containing duplicated contact numbers (within the output)

# %%
# -------------------------------
# Load the Excel file
# -------------------------------
file_path = r"C:\Users\teele\Documents\GitHub\Adhoc_Leads_Refinement_Pipeline\10k_adhoc_leads\Merged_Raw_Data\Merge_Kalai_and_Ish\Merged_Multiple_Raw_Data_Files_NoDuplicates.xlsx"
df = pd.read_excel(file_path)

# Standardize column names
df.columns = df.columns.str.strip().str.lower()

# -------------------------------
# 1️⃣ Email Address Constraints
# -------------------------------

# # Keep only emails ending with .sg or .com
# df = df[df['email_address'].str.lower().str.endswith(('.sg', '.com'), na=False)]

# # Remove rows where company_name is blank AND personal email
# personal_domains = ['gmail', 'yahoo', 'ymail', 'singnet', 'hotmail', 'outlook']
# mask_personal_email = df['company_name'].isna() & df['email_address'].str.lower().str.contains('|'.join(personal_domains), na=False)
# df = df[~mask_personal_email]

# Remove rows with marketing or entertainment in email address
df = df[~df['email_address'].str.lower().str.contains('marketing|entertainment', na=False)]

# Remove rows with delivery platforms in email address
delivery_platforms = ['deliveryhero', 'tabsquare', 'foodpanda', "grab"]
df = df[~df['email_address'].str.lower().str.contains('|'.join(delivery_platforms), na=False)]

# -------------------------------
# 2️⃣ Company Name Constraints
# -------------------------------

# Remove unwanted texts from company_name
unwanted_texts = [
    "SmartTerminals", "deal", "- Raptor List (Pay Only)", "Incoming Lead_", "FHA 2022_",
    "EDM leads _", "Google Ads Leads_", "Speedster Campaign_", "Fy23_", "TabsquareConneXions_",
    "QSR 2024 -", "Pre Event 2024-", "(SmartConnect)", "FP23_", "FY23_SG_RA_", "TabsquareConneXions_", ".. "
]
for text in unwanted_texts:
    df['company_name'] = df['company_name'].str.replace(text, '', case=False, regex=False)

# Remove unwanted symbols
df['company_name'] = df['company_name'].str.replace(r'[_*|]', '', regex=True)

# Remove rows containing "marketing" or "consulting" in company_name
df = df[~df['company_name'].str.lower().str.contains('marketing|consulting', na=False)]

# -------------------------------
# 3️⃣ Competitor Exclusion (from the email address)
# -------------------------------
competitors = [
    "suntoyo", "megasafe", "appzgate", "qashier", "weebo", "azdigital",
    "hashmicro", "netiquette", "edgeworks", "foodzaps", "sgdatahub", "imetrics", "possquare"
]

df = df[~df['email_address'].str.lower().str.contains('|'.join(competitors), na=False)]

# -------------------------------
# 4️⃣ Remove Duplicate Contact Numbers (keep first occurrence)
# -------------------------------

contact_cols = [f"contact_number {i}" for i in range(1, 9) if f"contact_number {i}" in df.columns]

seen_numbers = set()
rows_to_keep = []

for idx, row in df.iterrows():
    row_numbers = row[contact_cols].dropna().astype(str).tolist()
    if any(num in seen_numbers for num in row_numbers):
        continue  # skip row if any number is already seen
    else:
        seen_numbers.update(row_numbers)
        rows_to_keep.append(idx)

df = df.loc[rows_to_keep]

# -------------------------------
# 5️⃣ Remove duplicate email addresses for blank company_name
# -------------------------------
# Keep first occurrence only
mask_blank_company = df['company_name'].isna()
df_blank_company = df[mask_blank_company].drop_duplicates(subset=['email_address'], keep='first')
df_non_blank_company = df[~mask_blank_company]
df = pd.concat([df_non_blank_company, df_blank_company], ignore_index=True)

# -------------------------------
# 6️⃣ Split "email_address" into multiple columns
# -------------------------------
# Assuming emails are separated by commas
email_split = df['email_address'].str.split(',', expand=True)
email_split.columns = [f'email_{i+1}' for i in range(email_split.shape[1])]

# Concatenate split email columns to the original dataframe and drop original column
df = pd.concat([df.drop(columns=['email_address']), email_split], axis=1)

# -------------------------------
# 7️⃣ Format text columns
# -------------------------------
# Convert company_name to uppercase
df['company_name'] = df['company_name'].str.upper()

# Capitalize PIC names (first letter of each word)
df['pic_name'] = df['pic_name'].str.title()  # str.title() capitalizes first letter of each word

# -------------------------------
# 8️⃣ Keep only desired columns
# -------------------------------
columns_to_keep = [
    "company_name",
    "pic_name",
    "designation",
    "contact_number 1",
    "contact_number 2",
    "contact_number 3",
    "contact_number 4",
    "contact_number 5",
    "contact_number 6",
    "contact_number 7",
    "contact_number 8",
    "address"
]

# Include all split email columns
email_columns = [col for col in df.columns if col.startswith('email_')]
columns_to_keep += email_columns

columns_to_keep_existing = [col for col in columns_to_keep if col in df.columns]
df = df[columns_to_keep_existing]

# -------------------------------
# Save the cleaned data
# -------------------------------
output_file = "Merged_Multiple_Raw_Data_Files_NoDuplicates_Cleaned.xlsx"
df.to_excel(output_file, index=False)

print(f"Cleaning complete! Saved to {output_file}")
# Out:
# Cleaning complete! Saved to Merged_Multiple_Raw_Data_Files_NoDuplicates_Cleaned.xlsx

# %% [markdown]
# ### Categorise contact number according to their country of origin

# %%
import pandas as pd
import re

# --- Load your Excel file ---
file_path = r"C:\Users\teele\Documents\GitHub\Adhoc_Leads_Refinement_Pipeline\10k_adhoc_leads\Merged_Raw_Data\Merge_Kalai_and_Ish\Merged_Multiple_Raw_Data_Files_NoDuplicates_Cleaned.xlsx"
sheet_name = "Sheet1"
df = pd.read_excel(file_path, sheet_name=sheet_name)

# Column containing phone numbers
phone_col = "contact_number 1"

# --- Step 1: Clean numbers ---
def clean_number(number):
    if pd.isna(number):
        return ""
    # Remove everything except digits
    return re.sub(r"\D", "", str(number))

df["clean_number"] = df[phone_col].apply(clean_number)

# --- Step 2: Country dial codes ---
country_dial_codes = {
    "Singapore": "65",
    "Malaysia": "60",
    "Japan": "81",
    "Australia": "61",
    "China": "86",
    "Poland": "48",
    "Canada / USA": "1",
    "United Kingdom": "44",
    "India": "91",
    "Vietnam": "84",
    "Italy": "39",
    "Mongolia": "976",
    "British Indian Ocean Territory": "246",
    "Montenegro": "382",
    "Hong Kong": "852",
    "Belgium": "32",
    "South Africa": "27",
    "Libya": "218",
    "Ireland": "353",
    "Netherlands": "31",
    "Saudi Arabia": "966",
    "Taiwan": "886",
    "Anguilla": "264",
    "Indonesia": "62",
    "Saint Vincent & Grenadines": "784",
    "Philippines": "63",
    "Mexico": "52",
    "Thailand": "66",
    "Cambodia": "855",
    "Brunei": "673"
}

# --- Step 3: Detect country ---
def detect_country(number):
    if number.startswith("65") or (len(number) == 8 and number[0] in ["6","8","9"]):
        return "Singapore"
    elif number.startswith("60") or (len(number) in [9,10] and number.startswith("1")):
        return "Malaysia"
    elif number.startswith("81") or (len(number) == 10 and number.startswith("0")):
        return "Japan"
    elif number.startswith("61") or (len(number) == 9 and number.startswith("4")):
        return "Australia"
    elif number.startswith("86") or (len(number) == 11 and number.startswith("1")):
        return "China"
    elif len(number) == 9 and number[0] in ["5","6","7","8","9"]:
        return "Poland"
    elif len(number) == 10:
        return "Canada / USA"
    elif number.startswith("44"):
        return "United Kingdom"
    elif number.startswith("91"):
        return "India"
    elif number.startswith("84"):
        return "Vietnam"
    elif number.startswith("39"):
        return "Italy"
    elif number.startswith("976"):
        return "Mongolia"
    elif number.startswith("246"):
        return "British Indian Ocean Territory"
    elif number.startswith("382"):
        return "Montenegro"
    elif number.startswith("852"):
        return "Hong Kong"
    elif number.startswith("32"):
        return "Belgium"
    elif number.startswith("27"):
        return "South Africa"
    elif number.startswith("218"):
        return "Libya"
    elif number.startswith("353"):
        return "Ireland"
    elif number.startswith("31"):
        return "Netherlands"
    elif number.startswith("966"):
        return "Saudi Arabia"
    elif number.startswith("886"):
        return "Taiwan"
    elif number.startswith("264"):
        return "Anguilla"
    elif number.startswith("62"):
        return "Indonesia"
    elif number.startswith("784"):
        return "Saint Vincent & Grenadines"
    elif number.startswith("63"):
        return "Philippines"
    elif number.startswith("52"):
        return "Mexico"
    elif number.startswith("66"):
        return "Thailand"
    elif number.startswith("855"):
        return "Cambodia"
    elif number.startswith("673"):
        return "Brunei"
    else:
        return "Unknown"

# --- Step 4: Reformat numbers ---
def reformat_number(number, country):
    if not number:
        return ""
    
    number_only = number.lstrip("0")  # remove leading zero if present
    
    if country == "Singapore":
        # Format as +65 XXXX XXXX
        if number_only.startswith("65"):
            number_only = number_only[2:]
        if len(number_only) == 8:
            return f"+65 {number_only[:4]} {number_only[4:]}"
        else:
            return f"+65 {number_only}"  # fallback
    else:
        # Format as +<dial code> <remaining digits>
        dial_code = country_dial_codes.get(country, "")
        if number_only.startswith(dial_code):
            number_only = number_only[len(dial_code):]
        return f"+{dial_code} {number_only}"  # add space after dial code

# --- Step 5: Apply detection and formatting ---
df["country"] = df["clean_number"].apply(detect_country)
df["formatted_number"] = df.apply(lambda row: reformat_number(row["clean_number"], row["country"]), axis=1)

# --- Step 6: Save results ---
output_file = "Merged_Multiple_Raw_Data_Files_NoDuplicates_Cleaned_Contact Number Reformatted.xlsx"
df.to_excel(output_file, index=False)
print(f"✅ Saved categorized and formatted contacts to {output_file}")
# Out:
# ✅ Saved categorized and formatted contacts to Merged_Multiple_Raw_Data_Files_NoDuplicates_Cleaned_Contact Number Reformatted.xlsx

# %% [markdown]
# ### Reformatting contact number to Master DB format (65 XXXX XXXX)

# %%
# import pandas as pd
# import re

# file_path = "Ish_7.7k_Merged_Multiple_Raw_Data_Files_Cleaned.xlsx"
# df = pd.read_excel(file_path, dtype=str)  # read everything as string

# contact_cols = [
#     "contact_number 1", "contact_number 2", "contact_number 3", "contact_number 4",
#     "contact_number 5", "contact_number 6", "contact_number 7", "contact_number 8"
# ]

# def format_sg_number(number):
#     if pd.isna(number):
#         return None
#     # Remove any non-digit characters
#     digits = re.sub(r'\D', '', str(number))
    
#     # Remove leading zeroes (common if Excel stored as numeric)
#     digits = digits.lstrip('0')
    
#     # Handle 8-digit numbers
#     if len(digits) == 8:
#         return f"65 {digits[:4]} {digits[4:]}"
#     # Handle 10-digit numbers starting with 65
#     elif len(digits) == 10 and digits.startswith("65"):
#         return f"{digits[:2]} {digits[2:6]} {digits[6:]}"
#     else:
#         return number  # leave as is if format is unexpected

# # Apply formatting
# for col in contact_cols:
#     if col in df.columns:
#         df[col] = df[col].apply(format_sg_number)

# # Save the result
# df.to_excel("Ish_7.7k_Merged_Multiple_Raw_Data_Files_Cleaned_SG_Format.xlsx", index=False)
# print("✅ Contact numbers reformatted to SG format!")
# Out:
# ✅ Contact numbers reformatted to SG format!
