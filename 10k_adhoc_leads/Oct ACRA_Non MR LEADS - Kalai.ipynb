# %%
import pandas as pd
import glob
import os

# %%
# Load your filtered Excel file
filtered_file = "Filtered_Standardized_Deduped_Raw_Data.xlsx"
df_filtered = pd.read_excel(filtered_file)

# Standardize column names
df_filtered.columns = df_filtered.columns.str.strip().str.lower()
