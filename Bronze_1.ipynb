# %%
import os
import requests
import aiohttp
import asyncio
import nest_asyncio
import pandas as pd
import time
import scrapy
from scrapy_playwright.page import PageMethod
from bs4 import BeautifulSoup
import nest_asyncio
import glob
import numpy as np
import matplotlib.pyplot as plt
from fuzzywuzzy import fuzz, process
import re

# %% [markdown]
# ### Le Peng Data

# %%
# Load and clean dataset

df = (
    pd.read_excel('Non_MR_Leads_Le Peng.xlsx')
    .rename(columns=lambda c: c.upper().strip().replace(' ', '_').replace('-', '_'))
)

# Drop rows where COMPANY_NAME is NaN
company_names = df[['COMPANY_NAME', 'EMAIL_1', 'EMAIL_2', 'EMAIL_3']].dropna()

company_names.tail(50)
# Out:
#                                            COMPANY_NAME  \
# 6254          JIMMY MONKEY PTE LTD : JIMMY MONKEY @ PLQ
# 6260                                 K.I.T. F&B PTE LTD
# 6261                                 ISTEAKS @ TAMPINES
# 6281                                     KINMOO PTE LTD
# 6282                                 KINMOO THAI NOODLE
# 6310                          MAKAN MAKAN SINDO PTE LTD
# 6365                                      KOPITIAM @ T3
# 6380              CLASSIC - RWS (RESORTS WORLD SENTOSA)
# 6381                                         LENU @ RWS
# 6432           HONG KONG SHENG KEE DESSERT (BEDOK MALL)
# 6433          HONG KONG SHENG KEE DESSERT (COMPASS ONE)
# 6434         HONG KONG SHENG KEE DESSERT (HILLION MALL)
# 6435              HONG KONG SHENG KEE DESSERT (LOT ONE)
# 6436  HONG KONG SHENG KEE DESSERT (RAFFLES CITY SHOP...
# 6437         HONG KONG SHENG KEE DESSERT (TAMPINES ONE)
# 6438  HONG KONG SHENG KEE NOODLE HOUSE (TIONG BAHRU ...
# 6439                                   KAKI MAKAN - SGH
# 6440               LOU YAU BEAN SPROUTS CHICKEN PTE LTD
# 6441                              PHO STREET HONG LEONG
# 6442                          SHENG KEE DESSERT PTE LTD
# 6443                       SHENG KEE RESTAURANT PTE LTD
# 6444                                  TEXAS CHICKEN TSM
# 6445                            TEXAS HOLLAND CAPE VIEW
# 6447                               SEOUL GARDEN PTE LTD
# 6453                         SEOUL GARDEN @ HABOURFRONT
# 6472                          SINGAPORE RECREATION CLUB
# 6476                           SKYLINE CATERING PTE LTD
# 6495                                       TAI FENG WEI
# 6496      TAI FENG WEI : TAI FENG WEI FUSION - TAI SENG
# 6498                                   TANAMERA PTE LTD
# 6499                          TANAMERA @ ROBERTSON QUAY
# 6500                            TANAMERA @ TANGLIN MALL
# 6501                TANAMERA COFFEE @ NOVELTY TECHPOINT
# 6502                     TANAMERA COFFEE @ SGX CENTRE 2
# 6504                                TCS CENTRAL PTE LTD
# 6505                       TANAMERA COFFEE @ CIMB PLAZA
# 6506                    TANAMERA COFFEE @ MARINA SQUARE
# 6507                       TANAMERA COFFEE @ METROPOLIS
# 6508  TCS CENTRAL PTE LTD : TANAMERA COFFEE @ MYVILLAGE
# 6526                            TEXAS CHICKEN @ AMK 163
# 6535                               ROCKY MASTER (KINEX)
# 6537  THE COFFEE CONNECTION PTE LTD : ROCKY MASTER (...
# 6607                 LONG JOHN SILVER @ SINGPOST CENTRE
# 6609                      ZENSHO FOOD SINGAPORE PTE LTD
# 6610                      ZENSHO FOOD SINGAPORE PTE LTD
# 6611                      ZENSHO FOOD SINGAPORE PTE LTD
# 6612                      ZENSHO FOOD SINGAPORE PTE LTD
# 6613                           ZENSHO HOLDINGS CO., LTD
# 6623                       FILIPINO PRIME GRILL PTE LTD
# 6626                                   ZINGRILL PTE LTD
#
#                                EMAIL_1  \
# 6254             mavis@jimmymonkey.com
# 6260                yeow_tk@hsg.com.sg
# 6261                yeow_tk@hsg.com.sg
# 6281                 elton@holycrab.sg
# 6282                 elton@holycrab.sg
# 6310                morin.ng@gmail.com
# 6365    chew_hui.chan@fairprice.com.sg
# 6380     accounts@paradisegroup.com.sg
# 6381     accounts@paradisegroup.com.sg
# 6432                  IT@SELECT.COM.SG
# 6433                  IT@SELECT.COM.SG
# 6434                  IT@SELECT.COM.SG
# 6435                  IT@SELECT.COM.SG
# 6436                  IT@SELECT.COM.SG
# 6437                  IT@SELECT.COM.SG
# 6438                  IT@SELECT.COM.SG
# 6439                  IT@SELECT.COM.SG
# 6440                  IT@SELECT.COM.SG
# 6441                  IT@SELECT.COM.SG
# 6442                  IT@SELECT.COM.SG
# 6443                  IT@SELECT.COM.SG
# 6444                  IT@SELECT.COM.SG
# 6445                  IT@SELECT.COM.SG
# 6447  josephcheng@seoulgardengroup.com
# 6453  josephcheng@seoulgardengroup.com
# 6472              melvyn.it@src.org.sg
# 6476               finance@tanyusg.com
# 6495         pawanrak.t@taifengwei.com
# 6496         pawanrak.t@taifengwei.com
# 6498               susan.ji@winxam.com
# 6499               susan.ji@winxam.com
# 6500               susan.ji@winxam.com
# 6501               susan.ji@winxam.com
# 6502               susan.ji@winxam.com
# 6504               susan.ji@winxam.com
# 6505               susan.ji@winxam.com
# 6506               susan.ji@winxam.com
# 6507               susan.ji@winxam.com
# 6508               susan.ji@winxam.com
# 6526                  IT@SELECT.COM.SG
# 6535    shawjie.lou@rockymaster.com.sg
# 6537    shawjie.lou@rockymaster.com.sg
# 6607          chris.siut@sg.zensho.com
# 6609          chris.siut@sg.zensho.com
# 6610          chris.siut@sg.zensho.com
# 6611          chris.siut@sg.zensho.com
# 6612          chris.siut@sg.zensho.com
# 6613          chris.siut@sg.zensho.com
# 6623           rkctang@gerrysgrill.com
# 6626        celyn@seoulgardengroup.com
#
#                                      EMAIL_2                           EMAIL_3
# 6254                           alfred@ciy.sg                   accounts@ciy.sg
# 6260                 jennifer_sia@hsg.com.sg               Gina_lim@hsg.com.sg
# 6261                 jennifer_sia@hsg.com.sg               Gina_lim@hsg.com.sg
# 6281                   ruldoph.tan@gmail.com              kmngt@singnet.com.sg
# 6282                   ruldoph.tan@gmail.com              kmngt@singnet.com.sg
# 6310              Yenting.chia@finova.com.sg         andrew.soon@finova.com.sg
# 6365         vinoth_janarthanan@nedigital.sg      APquery_ne@ntucenterprise.sg
# 6380             yewyew@paradisegroup.com.sg      weiping@paradisegroup.com.sg
# 6381             yewyew@paradisegroup.com.sg      weiping@paradisegroup.com.sg
# 6432              meichoo_liew@select.com.sg           shelynlim@select.com.sg
# 6433              meichoo_liew@select.com.sg           shelynlim@select.com.sg
# 6434              meichoo_liew@select.com.sg           shelynlim@select.com.sg
# 6435              meichoo_liew@select.com.sg           shelynlim@select.com.sg
# 6436              meichoo_liew@select.com.sg           shelynlim@select.com.sg
# 6437              meichoo_liew@select.com.sg           shelynlim@select.com.sg
# 6438              meichoo_liew@select.com.sg           shelynlim@select.com.sg
# 6439              meichoo_liew@select.com.sg           shelynlim@select.com.sg
# 6440              meichoo_liew@select.com.sg           shelynlim@select.com.sg
# 6441              meichoo_liew@select.com.sg           shelynlim@select.com.sg
# 6442              meichoo_liew@select.com.sg           shelynlim@select.com.sg
# 6443              meichoo_liew@select.com.sg           shelynlim@select.com.sg
# 6444              meichoo_liew@select.com.sg           shelynlim@select.com.sg
# 6445              meichoo_liew@select.com.sg           shelynlim@select.com.sg
# 6447                   celyn@zingrill.com.sg        celyn@seoulgardengroup.com
# 6453                   celyn@zingrill.com.sg        celyn@seoulgardengroup.com
# 6472                   susan.purh@src.org.sg            carine.fnce@src.org.sg
# 6476                   operation@tanyusg.com             account_2@tanyusg.com
# 6495                 Sam.fong@taifengwei.com         Eunice.lim@taifengwei.com
# 6496                 Sam.fong@taifengwei.com         Eunice.lim@taifengwei.com
# 6498            dwi.tiara@tanameracoffee.com   ronald.liong@tanameracoffee.com
# 6499            dwi.tiara@tanameracoffee.com   ronald.liong@tanameracoffee.com
# 6500            dwi.tiara@tanameracoffee.com   ronald.liong@tanameracoffee.com
# 6501            dwi.tiara@tanameracoffee.com   ronald.liong@tanameracoffee.com
# 6502            dwi.tiara@tanameracoffee.com   ronald.liong@tanameracoffee.com
# 6504            dwi.tiara@tanameracoffee.com   ronald.liong@tanameracoffee.com
# 6505            dwi.tiara@tanameracoffee.com   ronald.liong@tanameracoffee.com
# 6506            dwi.tiara@tanameracoffee.com   ronald.liong@tanameracoffee.com
# 6507            dwi.tiara@tanameracoffee.com   ronald.liong@tanameracoffee.com
# 6508            dwi.tiara@tanameracoffee.com   ronald.liong@tanameracoffee.com
# 6526              meichoo_liew@select.com.sg           shelynlim@select.com.sg
# 6535    irene_tin@theconnoisseurconcerto.com       accounts@rockymaster.com.sg
# 6537    irene_tin@theconnoisseurconcerto.com       accounts@rockymaster.com.sg
# 6607                 peter.lim@sg.zensho.com         hayley.choy@sg.zensho.com
# 6609                 peter.lim@sg.zensho.com         hayley.choy@sg.zensho.com
# 6610                 peter.lim@sg.zensho.com         hayley.choy@sg.zensho.com
# 6611                 peter.lim@sg.zensho.com         hayley.choy@sg.zensho.com
# 6612                 peter.lim@sg.zensho.com         hayley.choy@sg.zensho.com
# 6613                  k-shimosato@zensho.com           peter.lim@sg.zensho.com
# 6623              Singapore2@gerrysgrill.com          wangping@gerrysgrill.com
# 6626        josephcheng@seoulgardengroup.com       meifun@seoulgardengroup.com

# %%
# from sentence_transformers import SentenceTransformer
# from sentence_transformers.util import cos_sim

# # Load the recommended model
# model = SentenceTransformer('Graphlet-AI/eridu')

# # Example company names
# names_list_1 = ["Silver Technologies Ltd.", "Silver Tech Pte Ltd"]
# names_list_2 = ["Goldman Sachs", "IBM Singapore"]

# # Generate embeddings
# embeddings_1 = model.encode(names_list_1)
# embeddings_2 = model.encode(names_list_2)

# # Calculate cosine similarity
# similarity_scores = cos_sim(embeddings_1, embeddings_2)

# print(similarity_scores)

# %%
folder_path = "Acra_Data"

# Get all CSV file paths inside the folder
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

# Read and combine all CSVs
# Using low_memory=False to avoid DtypeWarning for mixed types
df = pd.concat((pd.read_csv(f, low_memory=False) for f in csv_files), ignore_index=True)


df.columns = df.columns.str.upper()


acra_data = df[[
    "UEN",
    "ENTITY_NAME",
    "BUSINESS_CONSTITUTION_DESCRIPTION",
    "ENTITY_TYPE_DESCRIPTION",
    "ENTITY_STATUS_DESCRIPTION",
    "REGISTRATION_INCORPORATION_DATE",
    "PRIMARY_SSIC_CODE",
    "SECONDARY_SSIC_CODE",
    "STREET_NAME",
    "POSTAL_CODE"
]].copy()

# Convert to proper data types
acra_data['UEN'] = acra_data['UEN'].astype('string')
acra_data['ENTITY_NAME'] = acra_data['ENTITY_NAME'].astype('string')
acra_data['BUSINESS_CONSTITUTION_DESCRIPTION'] = acra_data['BUSINESS_CONSTITUTION_DESCRIPTION'].astype('string')
acra_data['ENTITY_TYPE_DESCRIPTION'] = acra_data['ENTITY_TYPE_DESCRIPTION'].astype('string')
acra_data['ENTITY_STATUS_DESCRIPTION'] = acra_data['ENTITY_STATUS_DESCRIPTION'].astype('string')
acra_data['REGISTRATION_INCORPORATION_DATE'] = pd.to_datetime(acra_data['REGISTRATION_INCORPORATION_DATE'], errors='coerce')

# Clean string columns — trim, remove extra spaces, uppercase
for col in [
    'UEN',
    'ENTITY_NAME',
    'BUSINESS_CONSTITUTION_DESCRIPTION',
    'ENTITY_TYPE_DESCRIPTION',
    'ENTITY_STATUS_DESCRIPTION',
    'STREET_NAME',
    'POSTAL_CODE'
]:
    acra_data[col] = (
        acra_data[col]
        .fillna('')
        .str.strip()
        .str.replace(r'\s+', ' ', regex=True)
        .str.upper()
    )

# Replace placeholders with NaN for standardization
acra_data.replace(['NA', 'N/A', '-', ''], np.nan, inplace=True)

# Convert registration date to dd-mm-yyyy string (optional)
acra_data['REGISTRATION_INCORPORATION_DATE'] = acra_data['REGISTRATION_INCORPORATION_DATE'].dt.strftime('%d-%m-%Y')

# Filter only live entities (LIVE COMPANY or LIVE)
acra_data = acra_data[
    acra_data['ENTITY_STATUS_DESCRIPTION'].isin(['LIVE COMPANY', 'LIVE'])
].reset_index(drop=True)

# Exclude specific PRIMARY_SSIC_CODE values (supposedly the data would be 600k plus but when we exclude this would lessen)
exclude_codes = [
    46900, 47719, 47749, 47539, 47536, 56123,
    10711, 10712, 10719, 10732, 10733, 93209
]

acra_data = acra_data[~acra_data['PRIMARY_SSIC_CODE'].isin(exclude_codes)].reset_index(drop=True)

# %%
acra_Names = acra_data[['ENTITY_NAME']].dropna()

# %%
acra_Names
# Out:
#                           ENTITY_NAME
# 0                       AIK SENG HENG
# 1                          ASIA STORE
# 2                       AIK CHE HIONG
# 3                  A WALIMOHAMED BROS
# 4       ANG TECK MOH DEPARTMENT STORE
# ...                               ...
# 537323               ZEUS BARBERS LLP
# 537324                ZENSE SPACE LLP
# 537325         ZIQZEQ PROCUREMENT LLP
# 537326           ZHONG XIN TRAVEL LLP
# 537327                 ZDT DRIVES LLP
#
# [537328 rows x 1 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def preprocess_company_name(name):
    """
    OPTIMIZED preprocessing for company names.
    Removes common suffixes, special characters, and standardizes format.
    """
    if pd.isna(name):
        return ""

    # Convert to string and uppercase
    name = str(name).upper().strip()

    # Remove special characters and punctuation (keep alphanumeric and spaces)
    name = re.sub(r'[^\w\s]', ' ', name)

    # Remove common company suffixes in order of longest to shortest to avoid partial matches
    suffixes = [
        'PRIVATE LIMITED', 'PTE LTD', 'PTE. LTD.', 'PTE LTD.', 'PTE. LTD',
        'PVT LTD', 'LIMITED', 'LTD', 'SINGAPORE', 'S.G.', 'SG', 'PTE',
        'COMPANY', 'CO', 'CORPORATION', 'CORP', 'INC', 'INCORPORATED',
        'LLC', 'LLP', 'PROPRIETARY', 'PROP'
    ]

    for suffix in suffixes:
        # Remove suffix if it appears at the end (with word boundary)
        if name.endswith(' ' + suffix):
            name = name[:-len(suffix)-1].strip()
        elif name == suffix:  # Handle case where name is only the suffix
            name = ""

    # Remove extra whitespace
    name = re.sub(r'\s+', ' ', name).strip()

    return name

# Preprocess both datasets
print("Preprocessing company names with optimized algorithm...")
company_names_clean = company_names['COMPANY_NAME'].apply(preprocess_company_name)
acra_names_clean = acra_Names['ENTITY_NAME'].apply(preprocess_company_name)

print(f"Company names to match: {len(company_names_clean):,}")
print(f"ACRA entities: {len(acra_names_clean):,}")

# OPTIMIZED TF-IDF Vectorizer with enhanced parameters
print("\nInitializing OPTIMIZED TF-IDF vectorizer...")

vectorizer = TfidfVectorizer(
    analyzer='char_wb',      # Character n-grams with word boundaries
    ngram_range=(2, 5),      # Extended to 5-grams for better context (OPTIMIZED)
    lowercase=True,
    max_df=0.90,             # More restrictive - ignore very common terms (OPTIMIZED)
    min_df=1,
    strip_accents='unicode',
    sublinear_tf=True        # Use sublinear term frequency scaling (OPTIMIZED)
)

# Fit the vectorizer on combined corpus for consistent vocabulary
print("Fitting vectorizer on combined corpus...")
all_names = pd.concat([company_names_clean, acra_names_clean], ignore_index=True)
vectorizer.fit(all_names)

# Transform both datasets
print("Transforming company names to TF-IDF vectors...")
tfidf_company = vectorizer.transform(company_names_clean)
tfidf_acra = vectorizer.transform(acra_names_clean)

print(f"\nTF-IDF matrix shape - Company names: {tfidf_company.shape}")
print(f"TF-IDF matrix shape - ACRA entities: {tfidf_acra.shape}")
print(f"Vocabulary size: {len(vectorizer.get_feature_names_out()):,} features")

# ============================================================================
# OPTIMIZED MEMORY-EFFICIENT BATCH PROCESSING
# ============================================================================
print("\n" + "="*70)
print("Computing similarities in BATCHES (optimized memory-efficient approach)")
print("This avoids creating a full similarity matrix (~22GB)")
print("="*70)

BATCH_SIZE = 100  # Process 100 companies at a time
PERFECT_THRESHOLD = 1.00  # Perfect matches (100%)
HIGH_QUALITY_THRESHOLD = 0.85  # High-quality matches (85-99%)
MINIMUM_THRESHOLD = 0.00  # Below 85%

perfect_matches = []
high_quality_matches = []
low_quality_matches = []

total_batches = (len(company_names) + BATCH_SIZE - 1) // BATCH_SIZE

for batch_num in range(total_batches):
    start_idx = batch_num * BATCH_SIZE
    end_idx = min(start_idx + BATCH_SIZE, len(company_names))

    # Compute similarity ONLY for this batch (saves memory)
    batch_similarities = cosine_similarity(tfidf_company[start_idx:end_idx], tfidf_acra)

    # Process each company in this batch
    for i, company_idx in enumerate(range(start_idx, end_idx)):
        scores = batch_similarities[i]

        # Find best match
        best_acra_idx = np.argmax(scores)
        best_score = scores[best_acra_idx]

        match_data = {
            'COMPANY_NAME': company_names.iloc[company_idx]['COMPANY_NAME'],
            'ENTITY_NAME': acra_data.iloc[best_acra_idx]['ENTITY_NAME'],
            'UEN': acra_data.iloc[best_acra_idx]['UEN'],
            'SIMILARITY_SCORE': round(best_score, 4),
            'ENTITY_STATUS': acra_data.iloc[best_acra_idx]['ENTITY_STATUS_DESCRIPTION'],
            'PRIMARY_SSIC_CODE': acra_data.iloc[best_acra_idx]['PRIMARY_SSIC_CODE'],
            'REGISTRATION_DATE': acra_data.iloc[best_acra_idx]['REGISTRATION_INCORPORATION_DATE']
        }

        # NEW: Categorize into 3 tiers based on score
        if best_score == PERFECT_THRESHOLD:
            perfect_matches.append(match_data)
        elif best_score >= HIGH_QUALITY_THRESHOLD:
            high_quality_matches.append(match_data)
        else:
            low_quality_matches.append(match_data)

    # Progress update every 10 batches
    if (batch_num + 1) % 10 == 0 or (batch_num + 1) == total_batches:
        progress = (end_idx / len(company_names)) * 100
        print(f"  Progress: {end_idx:,} / {len(company_names):,} companies ({progress:.1f}%)")

print("\n" + "="*70)
print("MATCHING COMPLETE!")
print("="*70)

# Create results dataframes with NEW 3-tier structure
perfect_match_df = pd.DataFrame(perfect_matches)
high_quality_df = pd.DataFrame(high_quality_matches)
low_quality_df = pd.DataFrame(low_quality_matches)

# Summary Statistics
print(f"\n{'='*70}")
print("SUMMARY STATISTICS")
print(f"{'='*70}")
print(f"Total companies processed: {len(company_names):,}")
print(f"\nPerfect Matches (100%):        {len(perfect_match_df):,} companies ({len(perfect_match_df)/len(company_names)*100:.2f}%)")
print(f"High-Quality Matches (85-99%): {len(high_quality_df):,} companies ({len(high_quality_df)/len(company_names)*100:.2f}%)")
print(f"Low-Quality Matches (<85%):    {len(low_quality_df):,} companies ({len(low_quality_df)/len(company_names)*100:.2f}%)")

# Perfect Match Statistics
if len(perfect_match_df) > 0:
    print(f"\n{'='*70}")
    print("PERFECT MATCHES (100%)")
    print(f"{'='*70}")
    print(f"  Total perfect matches: {len(perfect_match_df):,}")
    print(f"  These companies have exact or near-exact matches in ACRA database")

# High-Quality Match Statistics
if len(high_quality_df) > 0:
    print(f"\n{'='*70}")
    print("HIGH-QUALITY MATCHES (85%-99%)")
    print(f"{'='*70}")
    print(f"  Average similarity: {high_quality_df['SIMILARITY_SCORE'].mean():.4f}")
    print(f"  Median similarity:  {high_quality_df['SIMILARITY_SCORE'].median():.4f}")
    print(f"  Min similarity:     {high_quality_df['SIMILARITY_SCORE'].min():.4f}")
    print(f"  Max similarity:     {high_quality_df['SIMILARITY_SCORE'].max():.4f}")

    # Detailed breakdown
    print(f"\n  Quality Breakdown:")
    very_high = len(high_quality_df[(high_quality_df['SIMILARITY_SCORE'] >= 0.95)])
    high = len(high_quality_df[(high_quality_df['SIMILARITY_SCORE'] >= 0.90) & (high_quality_df['SIMILARITY_SCORE'] < 0.95)])
    good = len(high_quality_df[(high_quality_df['SIMILARITY_SCORE'] >= 0.85) & (high_quality_df['SIMILARITY_SCORE'] < 0.90)])

    print(f"    Very High (0.95-0.99): {very_high:,}")
    print(f"    High (0.90-0.94):      {high:,}")
    print(f"    Good (0.85-0.89):      {good:,}")

# Low-Quality Match Statistics
if len(low_quality_df) > 0:
    print(f"\n{'='*70}")
    print("LOW-QUALITY MATCHES (<85%)")
    print(f"{'='*70}")
    print(f"  Average similarity: {low_quality_df['SIMILARITY_SCORE'].mean():.4f}")
    print(f"  Median similarity:  {low_quality_df['SIMILARITY_SCORE'].median():.4f}")
    print(f"  Min similarity:     {low_quality_df['SIMILARITY_SCORE'].min():.4f}")
    print(f"  Max similarity:     {low_quality_df['SIMILARITY_SCORE'].max():.4f}")
    print(f"\n  ⚠ WARNING: These matches require manual verification!")

    # Additional breakdown for low quality
    print(f"\n  Score Distribution:")
    moderate = len(low_quality_df[(low_quality_df['SIMILARITY_SCORE'] >= 0.70)])
    fair = len(low_quality_df[(low_quality_df['SIMILARITY_SCORE'] >= 0.50) & (low_quality_df['SIMILARITY_SCORE'] < 0.70)])
    poor = len(low_quality_df[(low_quality_df['SIMILARITY_SCORE'] < 0.50)])

    print(f"    Moderate (0.70-0.84): {moderate:,}")
    print(f"    Fair (0.50-0.69):     {fair:,}")
    print(f"    Poor (<0.50):         {poor:,}")

print(f"\n{'='*70}")
print("DATAFRAMES CREATED:")
print(f"{'='*70}")
print(f"  perfect_match_df : {len(perfect_match_df):,} rows (100% similarity)")
print(f"  high_quality_df  : {len(high_quality_df):,} rows (85%-99% similarity)")
print(f"  low_quality_df   : {len(low_quality_df):,} rows (<85% similarity)")

print("\n✓ Optimization improvements:")
print("  - Enhanced preprocessing removes more special characters")
print("  - Extended n-grams (2-5) for better contextual matching")
print("  - Sublinear TF scaling reduces bias toward longer names")
print("  - More restrictive max_df filters common uninformative terms")
print("  - 3-tier classification (100%, 85-99%, <85%)")
# Out:
# Preprocessing company names with optimized algorithm...
# Company names to match: 7,589
# ACRA entities: 537,328
#
# Initializing OPTIMIZED TF-IDF vectorizer...
# Fitting vectorizer on combined corpus...
# Transforming company names to TF-IDF vectors...
#
# TF-IDF matrix shape - Company names: (7589, 509368)
# TF-IDF matrix shape - ACRA entities: (537328, 509368)
# Vocabulary size: 509,368 features
#
# ======================================================================
# Computing similarities in BATCHES (optimized memory-efficient approach)
# This avoids creating a full similarity matrix (~22GB)
# ======================================================================
#   Progress: 1,000 / 7,589 companies (13.2%)
#   Progress: 2,000 / 7,589 companies (26.4%)
#   Progress: 3,000 / 7,589 companies (39.5%)
#   Progress: 4,000 / 7,589 companies (52.7%)
#   Progress: 5,000 / 7,589 companies (65.9%)
#   Progress: 6,000 / 7,589 companies (79.1%)
#   Progress: 7,000 / 7,589 companies (92.2%)
#   Progress: 7,589 / 7,589 companies (100.0%)
#
# ======================================================================
# MATCHING COMPLETE!
# ======================================================================
#
# ======================================================================
# SUMMARY STATISTICS
# ======================================================================
# Total companies processed: 7,589
#
# Perfect Matches (100%):        238 companies (3.14%)
# High-Quality Matches (85-99%): 2,333 companies (30.74%)
# Low-Quality Matches (<85%):    5,018 companies (66.12%)
#
# ======================================================================
# PERFECT MATCHES (100%)
# ======================================================================
#   Total perfect matches: 238
#   These companies have exact or near-exact matches in ACRA database
#
# ======================================================================
# HIGH-QUALITY MATCHES (85%-99%)
# ======================================================================
#   Average similarity: 0.9630
#   Median similarity:  0.9876
#   Min similarity:     0.8502
#   Max similarity:     1.0000
#
#   Quality Breakdown:
#     Very High (0.95-0.99): 1,673
#     High (0.90-0.94):      284
#     Good (0.85-0.89):      376
#
# ======================================================================
# LOW-QUALITY MATCHES (<85%)
# ======================================================================
#   Average similarity: 0.6386
#   Median similarity:  0.6550
#   Min similarity:     0.0000
#   Max similarity:     0.8499
#
#   ⚠ WARNING: These matches require manual verification!
#
#   Score Distribution:
#     Moderate (0.70-0.84): 1,827
#     Fair (0.50-0.69):     2,455
#     Poor (<0.50):         736
#
# ======================================================================
# DATAFRAMES CREATED:
# ======================================================================
#   perfect_match_df : 238 rows (100% similarity)
#   high_quality_df  : 2,333 rows (85%-99% similarity)
#   low_quality_df   : 5,018 rows (<85% similarity)
#
# ✓ Optimization improvements:
#   - Enhanced preprocessing removes more special characters
#   - Extended n-grams (2-5) for better contextual matching
#   - Sublinear TF scaling reduces bias toward longer names
#   - More restrictive max_df filters common uninformative terms
#   - 3-tier classification (100%, 85-99%, <85%)

# %%
print(f"\n{'='*70}")
print("DATAFRAMES CREATED:")
print(f"{'='*70}")
print(f"  perfect_match_df : {len(perfect_match_df):,} rows (100% similarity)")
print(f"  high_quality_df  : {len(high_quality_df):,} rows (85%-99% similarity)")
print(f"  low_quality_df   : {len(low_quality_df):,} rows (<85% similarity)")
# Out:
# ======================================================================
# DATAFRAMES CREATED:
# ======================================================================
#   perfect_match_df : 238 rows (100% similarity)
#   high_quality_df  : 2,333 rows (85%-99% similarity)
#   low_quality_df   : 5,018 rows (<85% similarity)

# %%
high_quality_df.shape
# Out:
# (2333, 7)

# %%
high_quality_df.head(50)
# Out:
#                                        COMPANY_NAME  \
# 0                                     OXFORD ACUITY
# 1             HOSANNA FREIGHT AND LOGISTICS PTE LTD
# 2                                    YAMATO IZAKAYA
# 3                                          FOOD JOY
# 4                        TIONG HOE SPECIALTY COFFEE
# 5                                         BEST FOOD
# 6                                           WOK HEY
# 7                                    EG INNOVATIONS
# 8                                          WESTLAKE
# 9                                         MR KNEADY
# 10                                       BBQ MASTER
# 11                          INNOVATE QRLOCK PTE LTD
# 12                                         FAR EAST
# 13                                 MARINA BAY SANDS
# 14                                   TANG TEA HOUSE
# 15                                  BREADTALK GROUP
# 16                                               BT
# 17                                   BAKER AND COOK
# 18                                     SAKABA EIZOU
# 19                                               EB
# 20                                BLUE LABEL COFFEE
# 21                                         BROADWAY
# 22                                        PIZZAIOLA
# 23                                     ARTANS HOUSE
# 24                                           SPRUCE
# 25                                      IFS CAPITAL
# 26                                        ANONYMOUS
# 27                                       RESTAURANT
# 28                                              HRS
# 29                                              ERA
# 30                            ROYAL T GROUP PTE LTD
# 31                      CHILLI PADI HOLDING PTE LTD
# 32                                     TAN SOON MUI
# 33                                         OURGLASS
# 34                             200 HCM FOOD PTE LTD
# 35                2DEGREES NORTH COFFEE CO. PTE LTD
# 36                                     2SIX PTE LTD
# 37                       4FINGERS SINGAPORE PTE LTD
# 38               6IX 6IX RESTAURANT AND BAR PTE LTD
# 39                      7 INCH SQUARE PIZZA PTE LTD
# 40                        A MATTER OF TASTE PTE LTD
# 41  AAA MOKITA FOOD MANAGEMENT & CATERING PTE. LTD.
# 42                           ABC FOOD COURT PTE LTD
# 43                                 AC HESED PTE LTD
# 44                                ADDICTUDE PTE LTD
# 45                        ADIGAS RESTAURANT PTE LTD
# 46                    HCL LEASING & TRADING PTE LTD
# 47               AL-AZHAR EATING RESTAURANT PTE LTD
# 48                      AMBROSIA FINE FOODS PTE LTD
# 49                                AN HONEST CUP LLP
#
#                                         ENTITY_NAME         UEN  \
# 0                           OXFORD ACUITY PTE. LTD.  201838821K
# 1             HOSANNA FREIGHT & LOGISTICS PTE. LTD.  201421035D
# 2                        YAMATO IZAKAYA (PTE. LTD.)  201733803C
# 3                                FOOD-JOY PTE. LTD.  200408793M
# 4              TIONG HOE SPECIALTY COFFEE PTE. LTD.  201404489C
# 5                             E-BEST FOOD PTE. LTD.  202124742H
# 6                                 WOK HEY PTE. LTD.  201617998K
# 7                          EG INNOVATIONS PTE. LTD.  200100990G
# 8                              WESTLAKE 3 PTE. LTD.  200305400H
# 9                                      MR. KNEADY'S   53359762E
# 10                             BBQ MASTER PTE. LTD.  202231233G
# 11                        INNOVATE QRLOCK PTE. LTD.  201604075N
# 12                         C M R (FAR EAST) PTE LTD  198004382K
# 13                       MARINA BAY SANDS PTE. LTD.  200507292R
# 14                         TANG TEA HOUSE PTE. LTD.  200516377C
# 15                        BREADTALK GROUP PTE. LTD.  200302045G
# 16                                     BT PTE. LTD.  201903462C
# 17                           BAKER & COOK PTE. LTD.  201129634Z
# 18                                     SAKABA EIZOU   53458436E
# 19                                     EB PTE. LTD.  201524005W
# 20                      BLUE LABEL COFFEE PTE. LTD.  202230104H
# 21                                      BROADWAY CO   07119000K
# 22                              PIZZAIOLA PTE. LTD.  201015354N
# 23                                 ARTANS HOUSE LLP  T16LL1881F
# 24                          SPRUCE & NEST PTE. LTD.  202529489H
# 25                              IFS CAPITAL LIMITED  198700827C
# 26                    THE ANONYMOUS GROUP PTE. LTD.  202447153C
# 27                         S&M RESTAURANT PTE. LTD.  202304352N
# 28                                    HRS PTE. LTD.  200503075H
# 29                            ERA SINGAPORE PTE LTD  199003777Z
# 30                          ROYAL T GROUP PTE. LTD.  200916227W
# 31                    CHILLI PADI HOLDING PTE. LTD.  201712169H
# 32                           TAN SOON MUI PTE. LTD.  202038693H
# 33                               OURGLASS PTE. LTD.  201838325C
# 34                           200 HCM FOOD PTE. LTD.  201805711Z
# 35              2DEGREES NORTH COFFEE CO. PTE. LTD.  201434267Z
# 36                                   2SIX PTE. LTD.  201607584W
# 37                               4FINGERS PTE. LTD.  201430100G
# 38             6IX 6IX RESTAURANT AND BAR PTE. LTD.  201918613W
# 39                    7 INCH SQUARE PIZZA PTE. LTD.  201327685H
# 40                      A MATTER OF TASTE PTE. LTD.  201002922N
# 41  AAA MOKITA FOOD MANAGEMENT & CATERING PTE. LTD.  202012747H
# 42                         ABC FOOD COURT PTE. LTD.  202004790K
# 43                               AC HESED PTE. LTD.  197800043E
# 46            0.9899  LIVE COMPANY              77101        17-05-2019
# 47            0.9936  LIVE COMPANY              56111        19-06-2003
# 48            0.9931  LIVE COMPANY              56111        12-06-2019
# 49            0.9866  LIVE COMPANY              56112        28-02-2023

# %%
low_quality_df.shape
# Out:
# (5018, 7)

# %%
low_quality_compnaies = low_quality_df[["COMPANY_NAME"]]
low_quality_compnaies
# Out:
#                                            COMPANY_NAME
# 0                                  TAMJAI SAMGOR MIXIAN
# 1                                FAIR TRADE COMMODITIES
# 2                                             FORINTECH
# 3                                  THE DENZY COLLECTIVE
# 4                             INTERNATIONAL FOODGNOSTIC
# ...                                                 ...
# 5013                                           OVEREASY
# 5014                                HAN HOLDING COMPANY
# 5015  SINGAPORE BAKERY & CONFECTIONERY TRADE ASSOCIA...
# 5016                                       ROCKY MASTER
# 5017                                         GREEN LAKE
#
# [5018 rows x 1 columns]

# %% [markdown]
# ### Processing low quality data

# %%
if len(low_quality_df) > 0:
    print("="*70)
    print("RE-PROCESSING LOW-QUALITY MATCHES")
    print("Finding top 3 similar companies for manual review")
    print("="*70)
    
    # Extract company names from low_quality_df
    low_quality_companies = low_quality_df[['COMPANY_NAME']].drop_duplicates()
    
    print(f"\nProcessing {len(low_quality_companies):,} low-quality companies...")
    
    # Preprocess low-quality company names
    low_quality_clean = low_quality_companies['COMPANY_NAME'].apply(preprocess_company_name)
    
    # Transform to TF-IDF vectors using the existing vectorizer
    tfidf_low_quality = vectorizer.transform(low_quality_clean)
    
    # Process in batches to avoid memory issues
    BATCH_SIZE = 50  # Smaller batch size for top-3 processing
    TOP_N = 3  # Get top 3 matches
    
    enhanced_matches = []
    total_batches = (len(low_quality_companies) + BATCH_SIZE - 1) // BATCH_SIZE
    
    for batch_num in range(total_batches):
        start_idx = batch_num * BATCH_SIZE
        end_idx = min(start_idx + BATCH_SIZE, len(low_quality_companies))
        
        # Compute similarities for this batch
        batch_similarities = cosine_similarity(
            tfidf_low_quality[start_idx:end_idx], 
            tfidf_acra
        )
        
        # Process each company in the batch
        for i, company_idx in enumerate(range(start_idx, end_idx)):
            scores = batch_similarities[i]
            
            # Get top 3 match indices
            top_3_indices = np.argsort(scores)[::-1][:TOP_N]
            
            # Build match record
            match_record = {
                'COMPANY_NAME': low_quality_companies.iloc[company_idx]['COMPANY_NAME']
            }
            
            # Add top 3 matches
            for rank, acra_idx in enumerate(top_3_indices, 1):
                score = scores[acra_idx]
                match_record[f'MATCH_{rank}_ENTITY_NAME'] = acra_data.iloc[acra_idx]['ENTITY_NAME']
                match_record[f'MATCH_{rank}_UEN'] = acra_data.iloc[acra_idx]['UEN']
                match_record[f'MATCH_{rank}_SIMILARITY'] = round(score, 4)
                match_record[f'MATCH_{rank}_STATUS'] = acra_data.iloc[acra_idx]['ENTITY_STATUS_DESCRIPTION']
                match_record[f'MATCH_{rank}_SSIC'] = acra_data.iloc[acra_idx]['PRIMARY_SSIC_CODE']
            
            enhanced_matches.append(match_record)
        
        # Progress update
        if (batch_num + 1) % 5 == 0 or (batch_num + 1) == total_batches:
            progress = (end_idx / len(low_quality_companies)) * 100
            print(f"  Progress: {end_idx:,} / {len(low_quality_companies):,} companies ({progress:.1f}%)")
    
    # Create enhanced dataframe
    low_quality_enhanced_df = pd.DataFrame(enhanced_matches)
    
    print("\n" + "="*70)
    print("ENHANCED LOW-QUALITY DATAFRAME CREATED")
    print("="*70)
    print(f"  DataFrame: low_quality_enhanced_df")
    print(f"  Rows: {len(low_quality_enhanced_df):,}")
    print(f"  Columns: {len(low_quality_enhanced_df.columns)}")
    print(f"\n  Columns included:")
    print(f"    - COMPANY_NAME")
    print(f"    - MATCH_1_ENTITY_NAME, MATCH_1_UEN, MATCH_1_SIMILARITY, MATCH_1_STATUS, MATCH_1_SSIC")
    print(f"    - MATCH_2_ENTITY_NAME, MATCH_2_UEN, MATCH_2_SIMILARITY, MATCH_2_STATUS, MATCH_2_SSIC")
    print(f"    - MATCH_3_ENTITY_NAME, MATCH_3_UEN, MATCH_3_SIMILARITY, MATCH_3_STATUS, MATCH_3_SSIC")
    
    # Show statistics
    print(f"\n  Top Match Statistics:")
    print(f"    Average similarity (Match 1): {low_quality_enhanced_df['MATCH_1_SIMILARITY'].mean():.4f}")
    print(f"    Average similarity (Match 2): {low_quality_enhanced_df['MATCH_2_SIMILARITY'].mean():.4f}")
    print(f"    Average similarity (Match 3): {low_quality_enhanced_df['MATCH_3_SIMILARITY'].mean():.4f}")
    
    # Count how many now exceed 80% threshold
    high_quality_promoted = len(low_quality_enhanced_df[low_quality_enhanced_df['MATCH_1_SIMILARITY'] >= 0.80])
    if high_quality_promoted > 0:
        print(f"\n  ⚠ NOTE: {high_quality_promoted} companies now have Match 1 >= 80%")
        print(f"         Consider reviewing these for promotion to high-quality matches")
    
    print("\nShowing first 10 enhanced low-quality matches:")
    low_quality_enhanced_df.head(10)
else:
    print("\nNo low-quality matches to enhance (all matches were either high-quality or no match).")
    low_quality_enhanced_df = pd.DataFrame()
# Out:
# ======================================================================
# RE-PROCESSING LOW-QUALITY MATCHES
# Finding top 3 similar companies for manual review
# ======================================================================
#
# Processing 4,498 low-quality companies...
#   Progress: 250 / 4,498 companies (5.6%)
#   Progress: 500 / 4,498 companies (11.1%)
#   Progress: 750 / 4,498 companies (16.7%)
#   Progress: 1,000 / 4,498 companies (22.2%)
#   Progress: 1,250 / 4,498 companies (27.8%)
#   Progress: 1,500 / 4,498 companies (33.3%)
#   Progress: 1,750 / 4,498 companies (38.9%)
#   Progress: 2,000 / 4,498 companies (44.5%)
#   Progress: 2,250 / 4,498 companies (50.0%)
#   Progress: 2,500 / 4,498 companies (55.6%)
#   Progress: 2,750 / 4,498 companies (61.1%)
#   Progress: 3,000 / 4,498 companies (66.7%)
#   Progress: 3,250 / 4,498 companies (72.3%)
#   Progress: 3,500 / 4,498 companies (77.8%)
#   Progress: 3,750 / 4,498 companies (83.4%)
#   Progress: 4,000 / 4,498 companies (88.9%)
#   Progress: 4,250 / 4,498 companies (94.5%)
#   Progress: 4,498 / 4,498 companies (100.0%)
#
# ======================================================================
# ENHANCED LOW-QUALITY DATAFRAME CREATED
# ======================================================================
#   DataFrame: low_quality_enhanced_df
#   Rows: 4,498
#   Columns: 16
#
#   Columns included:
#     - COMPANY_NAME
#     - MATCH_1_ENTITY_NAME, MATCH_1_UEN, MATCH_1_SIMILARITY, MATCH_1_STATUS, MATCH_1_SSIC
#     - MATCH_2_ENTITY_NAME, MATCH_2_UEN, MATCH_2_SIMILARITY, MATCH_2_STATUS, MATCH_2_SSIC
#     - MATCH_3_ENTITY_NAME, MATCH_3_UEN, MATCH_3_SIMILARITY, MATCH_3_STATUS, MATCH_3_SSIC
#
#   Top Match Statistics:
#     Average similarity (Match 1): 0.6409
#     Average similarity (Match 2): 0.5763
#     Average similarity (Match 3): 0.5454
#
#   ⚠ NOTE: 405 companies now have Match 1 >= 80%
#          Consider reviewing these for promotion to high-quality matches
#
# Showing first 10 enhanced low-quality matches:

# %%
low_quality_enhanced_df.tail(50)
# Out:
#                                            COMPANY_NAME  \
# 4448                                        ROCK MASTER
# 4449                                DOLPHINS RESTAURANT
# 4450                          DORSETT SINGAPORE (HOTEL)
# 4451                                         TOMETO LLP
# 4452                            LAGNAA BARE FOOT DINING
# 4453                                              BADEN
# 4454                                   SHIJI / INFRASYS
# 4455                                             GECORY
# 4456                                   SOI 47 THAI FOOD
# 4457                                              VATOS
# 4458                                   AUNTIE TEO PLACE
# 4459                                              SPIZE
# 4460                                   J'S WOK & GRILL
# 4461                          JUZ BREAD HOLDING PTE LTD
# 4462                                          GONG CHA
# 4463                                             VATOS
# 4464                                          BAN HENG
# 4465                               EATS MY LIFE PTD LTD
# 4466                                 FISH MART SAKURAYA
# 4467               WILD WILD WET & NEW ZEALAND NATURAL
# 4468                                ICHIBAN GROUP/RE&S
# 4469                                           AROY DEE
# 4470                                       VEGAN BERG.
# 4471                              STAMFORDLAND HOLDINGS
# 4472                               QUAFFER ASIA PACIFIC
# 4473                               SELETAR COUNTRY CLUB
# 4474                                        ROMA GELATO
# 4475                     HARD ROCK CAFE/JAMIE'S ITALIAN
# 4476                                  PETITE BAKE HOUSE
# 4477                      SINGAPORE ISLAND COUNTRY CLUB
# 4478                               BURGER KING MONGOLIA
# 4479                            SWENSENS / ABR HOLDINGS
# 4480                                    JADON SOLUTIONS
# 4481                              ISHIKAWA CONSULTANCY
# 4482                                           BAN HENG
# 4483                                          99 BISTRO
# 4484              BREWERKS / EASY & LIGHT GROUP PTE LTD
# 4485                             UMI SUSHI / NEO GROUP
# 4486                                   SIMPLUS SOLUTION
# 4487                          ASIAN CULINARY INSTITUTE
# 4488                                TEMASEK POLYTECHNIC
# 4489                                             ZUMATA
# 4490      SIPI (SG INNOVATION & PRODUCTIVITY INSTITUTE)
# 4491                                           VIEGREEN
# 4492                                          POCO LOCO
# 4493                                      CFC INDONESIA
# 4494                                       EMBASSY PERU
# 4495                                HAN HOLDING COMPANY
# 4496  SINGAPORE BAKERY & CONFECTIONERY TRADE ASSOCIA...
# 4497                                         GREEN LAKE
#
#                                     MATCH_1_ENTITY_NAME MATCH_1_UEN  \
# 4448                                 MASTER I PTE. LTD.  202212978N
# 4470              0.5700           LIVE         46223
# 4471              0.6407   LIVE COMPANY         82999
# 4472              0.5391   LIVE COMPANY         64202
# 4473              0.6174   LIVE COMPANY         85409
# 4474              0.7400           LIVE         56112
# 4475              0.4657   LIVE COMPANY         63203
# 4476              0.6180           LIVE         47712
# 4477              0.5612   LIVE COMPANY         93111
# 4478              0.6503   LIVE COMPANY         64202
# 4479              0.6123   LIVE COMPANY         47219
# 4480              0.5616           LIVE         70201
# 4481              0.5234   LIVE COMPANY         73200
# 4482              0.6931           LIVE         46411
# 4483              0.7683   LIVE COMPANY         56111
# 4484              0.4842   LIVE COMPANY         70205
# 4485              0.5799   LIVE COMPANY         56122
# 4486              0.6812           LIVE         70201
# 4487              0.6993   LIVE COMPANY         85302
# 4488              0.5820   LIVE COMPANY         96099
# 4489              0.4376   LIVE COMPANY         47102
# 4490              0.5384   LIVE COMPANY         47529
# 4491              0.3667   LIVE COMPANY         38100
# 4492              0.7195           LIVE         90009
# 4493              0.7245   LIVE COMPANY         68101
# 4494              0.7664   LIVE COMPANY         74191
# 4495              0.7183   LIVE COMPANY         86201
# 4496              0.7202           LIVE         47219
# 4497              0.7127   LIVE COMPANY         64202
#
#                          MATCH_3_ENTITY_NAME MATCH_3_UEN  MATCH_3_SIMILARITY  \
# 4448                          ROCK PTE. LTD.  201609094K              0.6645
# 4449      DOLPHINS MARINE SUPPLIES PTE. LTD.  202031499K              0.5912
# 4450           DORSETT CHANGI CITY SINGAPORE   53216816W              0.5966
# 4451                       TOMEDIA PTE. LTD.  202332464E              0.3715
# 4452                      E-DINING PTE. LTD.  200809810D              0.4073
# 4453                      ADEN E&C PTE. LTD.  201906102K              0.4109
# 4454                        ORASYS PTE. LTD.  201908574M              0.4149
# 4455                      INGECORE PTE. LTD.  200510978C              0.3297
# 4456                      SOI THAI PTE. LTD.  201833682G              0.7244
# 4457               VATOS URBAN MIX PTE. LTD.  201927200R              0.6679
# 4458                   BEER AUNTIE PTE. LTD.  201927961E              0.5973
# 4459                   SPIZE BEDOK PTE. LTD.  200718147N              0.7404
# 4460                         J'S BAR & GRILL   53190634E              0.6827
# 4461                   BREAD & CO. PTE. LTD.  201628383K              0.6013
# 4462                     GONG TING PTE. LTD.  201025696H              0.6189
# 4463               VATOS URBAN MIX PTE. LTD.  201927200R              0.6679
# 4464                HENG HENG HENG PTE. LTD.  202441136K              0.6883
# 4465                          EATS PTE. LTD.  202008151H              0.5618
# 4466                              RED SAKURA   53436189K              0.5093
# 4467                              WEE & WILD   53509596A              0.5030
# 4468                           ICHIBAN SUSHI   53273556X              0.6955
# 4469                      SOI AROY PTE. LTD.  201736347M              0.6228
# 4470                          WORLD OF VEGAN   53504204C              0.5662
# 4471                 STAMFORD LAND PTE. LTD.  200103615E              0.6339
# 4472              E-T-A ASIA PACIFIC PTE LTD  199700437C              0.5378
# 4473                UNCOUNTRY CLUB PTE. LTD.  202431004W              0.5643
# 4474                          HAY GELATO LLP  T16LL0108K              0.6807
# 4475                            ITALIAN FOOD   53436144K              0.4452
# 4476                     LM PETITE PTE. LTD.  202216115N              0.6029
